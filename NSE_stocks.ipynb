# %%
import nsepy
from datetime import date
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
infy = get_history(symbol='INFY',start=date(2015,1,1),end=date(2015,12,31))

tcs = get_history(symbol='TCS',start=date(2015,1,1),end=date(2015,12,31))

# %%
infy['Close'].plot(figsize=(20,10))
tcs['Close'].plot(figsize=(20,10), color='red')

# %%
maximum_price = infy['Close'].max()
print(maximum_price)
print('\n')
max_price = tcs['Close'].max()
print(max_price)
# Out:
# 2324.7
#
#
# 2776.0

# %%
infy['Percent_Change'] = infy['Close'].pct_change()*100
dt= (infy[infy.Percent_Change > 1.0])
infy.head()
# Out:
#            Symbol Series  Prev Close     Open     High     Low     Last  \
# Date
# 2015-01-01   INFY     EQ     1972.55  1968.95  1982.00  1956.9  1971.00
# 2015-01-02   INFY     EQ     1974.40  1972.00  2019.05  1972.0  2017.95
# 2015-01-05   INFY     EQ     2013.20  2009.90  2030.00  1977.5  1996.00
# 2015-01-06   INFY     EQ     1995.90  1980.00  1985.00  1934.1  1965.10
# 2015-01-07   INFY     EQ     1954.20  1965.00  1974.75  1950.0  1966.05
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2015-01-01  1974.40  1971.34   500691  9.870306e+13   14908
# 2015-01-02  2013.20  2003.25  1694580  3.394669e+14   54166
# 2015-01-05  1995.90  2004.59  2484256  4.979911e+14   82694
# 2015-01-06  1954.20  1954.82  2416829  4.724458e+14  108209
# 2015-01-07  1963.55  1962.59  1812479  3.557162e+14   62463
#
#             Deliverable Volume  %Deliverble  Percent_Change
# Date
# 2015-01-01              258080       0.5154             NaN
# ...

# %%
infy['Date']=infy.index

tcs['Date']=tcs.index

# %%
infy.columns
# Out:
# Index([u'Symbol', u'Series', u'Prev Close', u'Open', u'High', u'Low', u'Last',
#        u'Close', u'VWAP', u'Volume', u'Turnover', u'Trades',
#        u'Deliverable Volume', u'%Deliverble', u'Percent_Change', u'Date',
#        u'Week', u'moving_avg_forecast'],
#       dtype='object')

# %%
infy['Date'] = pd.to_datetime(infy['Date'])
infy['Week'] = infy['Date'].dt.week

tcs['Date'] = pd.to_datetime(tcs['Date'])
tcs['Week'] = tcs['Date'].dt.week

# %%
print(infy)
print('\n')
print(tcs)
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2015-01-19   INFY     EQ     2118.30  2120.00  2132.35  2094.60  2105.00
# 2015-01-20   INFY     EQ     2102.50  2107.00  2133.00  2101.45  2119.20
# 2015-01-21   INFY     EQ     2124.20  2131.50  2175.95  2118.00  2172.00
# 2015-01-22   INFY     EQ     2169.90  2174.80  2203.00  2161.30  2194.95
# 2015-01-23   INFY     EQ     2196.45  2200.00  2225.00  2165.10  2211.90
# 2015-02-16   INFY     EQ     2296.10  2280.30  2306.90  2265.25  2282.00
# 2015-02-18   INFY     EQ     2278.75  2290.55  2304.95  2258.15  2292.05
# 2015-02-19   INFY     EQ     2296.50  2294.00  2334.00  2292.05  2323.20
# 2015-02-20   INFY     EQ     2324.70  2328.50  2336.00  2276.90  2280.50
# 2015-03-16   INFY     EQ     2220.40  2210.55  2282.00  2210.55  2261.00
# 2015-03-17   INFY     EQ     2266.65  2266.65  2279.50  2217.25  2245.00
# 2015-03-18   INFY     EQ     2240.50  2254.50  2262.85  2222.55  2233.00
# ...

# %%
week=range(4,56,4)
infy=infy.loc[infy['Week'].isin(week)]

tcs=tcs.loc[tcs['Week'].isin(week)]

# %%
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2015-01-19   INFY     EQ     2118.30  2120.00  2132.35  2094.60  2105.00
# 2015-01-20   INFY     EQ     2102.50  2107.00  2133.00  2101.45  2119.20
# 2015-01-21   INFY     EQ     2124.20  2131.50  2175.95  2118.00  2172.00
# 2015-01-22   INFY     EQ     2169.90  2174.80  2203.00  2161.30  2194.95
# 2015-01-23   INFY     EQ     2196.45  2200.00  2225.00  2165.10  2211.90
# 2015-02-16   INFY     EQ     2296.10  2280.30  2306.90  2265.25  2282.00
# 2015-02-18   INFY     EQ     2278.75  2290.55  2304.95  2258.15  2292.05
# 2015-02-19   INFY     EQ     2296.50  2294.00  2334.00  2292.05  2323.20
# 2015-02-20   INFY     EQ     2324.70  2328.50  2336.00  2276.90  2280.50
# 2015-03-16   INFY     EQ     2220.40  2210.55  2282.00  2210.55  2261.00
# 2015-03-17   INFY     EQ     2266.65  2266.65  2279.50  2217.25  2245.00
# 2015-03-18   INFY     EQ     2240.50  2254.50  2262.85  2222.55  2233.00
# ...

# %%
infy['moving_avg_forecast'] = infy.Close.rolling(10).mean()
plt.figure(figsize=(20,10))
plt.plot(infy['Close'], label='Close')
plt.plot(infy['moving_avg_forecast'], label='Moving Average Forecast')
plt.legend(loc='best')
plt.show()

tcs['moving_avg_forecast'] = tcs.Close.rolling(10).mean()
plt.figure(figsize=(20,10))
plt.plot(tcs['Close'], label='Close')
plt.plot(tcs['moving_avg_forecast'], label='Moving Average Forecast')
plt.legend(loc='best')
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
